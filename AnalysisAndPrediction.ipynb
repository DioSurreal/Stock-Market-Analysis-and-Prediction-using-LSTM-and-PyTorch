# %%
# !pip install yfinance

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline
import yfinance as yf
# For reading stock data from yahoo


yf.pdr_override()

from datetime import datetime
# Out:
# yfinance: pandas_datareader support is deprecated & semi-broken so will be removed in a future verison. Just use yfinance.

# %%
tech_list = ['AAPL', 'GOOG', 'MSFT', 'AMZN','META']

end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)

for stock in tech_list:
    globals()[stock] = yf.download(stock, start, end)
    

company_list = [AAPL, GOOG, MSFT, AMZN, META]
company_name = ["APPLE", "GOOGLE", "MICROSOFT", "AMAZON","META"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
AAPL.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   190.950079  192.726389  189.320952  191.089683  190.582289
# std     18.864392   19.104115   18.438058   18.778949   18.953683
# min    165.350006  166.399994  164.080002  165.000000  164.585999
# 25%    175.480003  177.442505  173.850002  175.677505  174.799145
# 50%    187.094994  188.370003  185.834999  187.014999  186.672180
# 75%    196.899994  198.099998  195.124996  197.667507  196.920254
# max    236.479996  237.229996  233.089996  234.820007  234.548523
#
#              Volume
# count  2.520000e+02
# mean   5.969215e+07
# std    2.507594e+07
# min    2.404830e+07
# 25%    4.604935e+07
# 50%    5.340020e+07
# 75%    6.573822e+07
# max    2.464214e+08

# %%
GOOG.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   153.197096  154.763444  151.827980  153.321547  153.195974
# std     17.916906   18.064274   17.762407   17.856141   17.894634
# min    124.029999  124.440002  121.459999  123.400002  123.259735
# 25%    138.187500  139.502502  137.067505  138.412498  138.255177
# 50%    148.750000  149.887497  147.504997  148.579994  148.411110
# 75%    168.837502  169.977497  166.435001  168.749996  168.709476
# max    191.750000  193.309998  190.619995  192.660004  192.660004
#
#              Volume
# count  2.520000e+02
# mean   2.067650e+07
# std    8.235380e+06
# min    7.409100e+06
# 25%    1.607578e+07
# 50%    1.849675e+07
# 75%    2.259408e+07
# max    5.972800e+07

# %%
MSFT.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   395.856111  398.911827  392.366746  395.837977  394.282320
# std     37.950216   37.966388   37.654707   37.880768   38.446340
# min    310.989990  314.299988  309.450012  312.140015  309.814545
# 25%    371.264999  374.400002  368.637497  372.617493  370.592072
# 50%    407.619995  410.074997  403.900009  406.610001  405.243484
# 75%    420.832504  424.632507  417.592506  421.415001  419.976654
# max    467.000000  468.350006  464.459991  467.559998  466.718781
#
#              Volume
# count  2.520000e+02
# mean   2.202259e+07
# std    8.066524e+06
# min    9.932800e+06
# 25%    1.681705e+07
# 50%    2.034405e+07
# 75%    2.485222e+07
# max    7.847820e+07

# %%
AMZN.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   164.907064  166.639920  163.061865  164.935794  164.935794
# std     21.006081   21.026835   20.733038   20.807486   20.807486
# min    120.629997  121.639999  118.349998  119.570000  119.570000
# 25%    146.112495  147.705006  145.315006  146.845005  146.845005
# 50%    172.894997  174.379997  170.985001  172.229996  172.229996
# 75%    181.712498  183.944996  179.962498  181.387501  181.387501
# max    200.089996  201.199997  199.050003  200.000000  200.000000
#
#              Volume
# count  2.520000e+02
# mean   4.559522e+07
# std    1.700889e+07
# min    2.236620e+07
# 25%    3.405970e+07
# 50%    4.270560e+07
# 75%    5.093890e+07
# max    1.414484e+08

# %%
META.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   427.030675  432.706388  421.782341  427.400992  426.926268
# std     83.177896   84.025134   81.742682   82.670060   82.846437
# min    294.480011  295.000000  279.399994  288.350006  287.758667
# 25%    334.387505  338.595001  332.285011  334.875008  334.188271
# 50%    467.899994  473.275009  462.029999  468.069992  467.555786
# 75%    499.349991  504.507507  493.220009  497.852493  497.706894
# max    542.349976  544.229980  528.590027  539.909973  539.909973
#
#              Volume
# count  2.520000e+02
# mean   1.693531e+07
# std    9.145011e+06
# min    5.467500e+06
# 25%    1.176262e+07
# 50%    1.531610e+07
# 75%    1.924830e+07
# max    8.461550e+07

# %%
#Closing Price
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(3, 2, i)
    company['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"Closing Price of {tech_list[i - 1]}")
    
plt.tight_layout()

# %%
#Market trading volume
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(3, 2, i)
    company['Volume'].plot()
    plt.ylabel('Volume')
    plt.xlabel(None)
    plt.title(f"Sales Volume for {tech_list[i - 1]}")
    
plt.tight_layout()

# %%
#moving average of the various stocks
ma_day = [10, 20, 50]

for ma in ma_day:
    for company in company_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Adj Close'].rolling(ma).mean()
        

fig, axes = plt.subplots(nrows=3, ncols=2)
fig.set_figheight(10)
fig.set_figwidth(15)

AAPL[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,0])
axes[0,0].set_title('APPLE')

GOOG[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,1])
axes[0,1].set_title('GOOGLE')

MSFT[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,0])
axes[1,0].set_title('MICROSOFT')

AMZN[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,1])
axes[1,1].set_title('AMAZON')

META[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[2,0])
axes[2,0].set_title('META')

fig.tight_layout()

# %%
for company in company_list:
    company['Daily Return'] = company['Adj Close'].pct_change()

fig, axes = plt.subplots(nrows=3, ncols=2)
fig.set_figheight(10)
fig.set_figwidth(15)

AAPL['Daily Return'].plot(ax=axes[0,0], legend=True, linestyle='--', marker='o')
axes[0,0].set_title('APPLE')

GOOG['Daily Return'].plot(ax=axes[0,1], legend=True, linestyle='--', marker='o')
axes[0,1].set_title('GOOGLE')

MSFT['Daily Return'].plot(ax=axes[1,0], legend=True, linestyle='--', marker='o')
axes[1,0].set_title('MICROSOFT')

AMZN['Daily Return'].plot(ax=axes[1,1], legend=True, linestyle='--', marker='o')
axes[1,1].set_title('AMAZON')

META['Daily Return'].plot(ax=axes[2,0], legend=True, linestyle='-',marker='o')
axes[2,0].set_title('META(Facebook)')

fig.tight_layout()

# %%
plt.figure(figsize=(12, 9))

for i, company in enumerate(company_list, 1):
    plt.subplot(3, 2, i)
    company['Daily Return'].hist(bins=50)
    plt.xlabel('Daily Return')
    plt.ylabel('Counts')
    plt.title(f'{company_name[i - 1]}')
    
plt.tight_layout()

# %%
#correlation between different stocks closing prices

closing_df = yf.download(tech_list, start=start, end=end)['Adj Close']


tech_rets = closing_df.pct_change()
tech_rets.head()
# Out:
# [*********************100%%**********************]  5 of 5 completed
# Ticker          AAPL      AMZN      GOOG      META      MSFT
# Date
# 2023-09-07       NaN       NaN       NaN       NaN       NaN
# 2023-09-08  0.003492  0.002757  0.007342 -0.002612  0.013216
# 2023-09-11  0.006623  0.035231  0.003936  0.032462  0.010979
# 2023-09-12 -0.017061 -0.013068 -0.012124 -0.019183 -0.018258
# 2023-09-13 -0.011855  0.025632  0.010509  0.011271  0.012931

# %%
plt.figure(figsize=(12, 8))

sns.heatmap(tech_rets.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.show()

# %%
#predcit 

# df_AAPL = yf.download('AAPL', start='2012-01-01', end=datetime.now())
# df_GOOG = yf.download('GOOG', start='2012-01-01', end=datetime.now())
# df_MSFT = yf.download('MSFT', start='2012-01-01', end=datetime.now())
# df_AMZN = yf.download('AMZN', start='2012-01-01', end=datetime.now())
# df_META = yf.download('META', start='2012-01-01', end=datetime.now())
df_name =['df_AAPL', 'df_GOOG', 'df_MSFT', 'df_AMZN','df_META']
start_model  = datetime(end.year - 10, end.month, end.day)

for df_n,stock_n in zip(df_name,tech_list):
    globals()[df_n] = yf.download(stock_n, start_model, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
df_AAPL.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2014-09-08  24.825001  24.827499  24.512501  24.590000  21.833637  185426800
# 2014-09-09  24.770000  25.770000  24.035000  24.497499  21.751511  759385200
# 2014-09-10  24.502501  25.277500  24.440001  25.250000  22.419655  403478400
# 2014-09-11  25.102501  25.360001  24.905001  25.357500  22.515108  249412400
# 2014-09-12  25.302500  25.547501  25.270000  25.415001  22.566162  250504400

# %%
for df_n,title_n in zip(df_name,company_name):
   
    plt.figure(figsize=(16,6))
    plt.title('Close Price History of '+ title_n)
    plt.plot(eval(df_n)['Close'])
    plt.xlabel('Date', fontsize=18)
    plt.ylabel('Close Price USD ($)', fontsize=18)
    plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler


#close_data = ['scaled_AAPL', 'scaled_GOOG', 'scaled_MSFT', 'scaled_AMZN','scaled_META']

def scalingData(df_name):
    data = df_name.filter(['Close'])  # กรองเฉพาะคอลัมน์ 'Close'
    dataset = data.values  # แปลง DataFrame เป็น numpy array
    scaler = MinMaxScaler(feature_range=(0,1))  # สร้างตัวปรับสเกล MinMaxScaler
    close_arr_scale = scaler.fit_transform(dataset)  # ทำการปรับสเกลข้อมูล
    return close_arr_scale
#ลองเช็คอีกทีว่าshapeข้ออมูลไปแล้วหรือยัง shapeแล้ว

# %%
scaled_AAPL = scalingData(df_AAPL) 
scaled_GOOG = scalingData(df_GOOG) 
scaled_MSFT = scalingData(df_MSFT) 
scaled_AMZN = scalingData(df_AMZN) 
scaled_META = scalingData(df_META) 
print(scaled_META.shape)
# Out:
# (2517, 1)

# %%
arr_dataset = [df_AAPL,df_GOOG,df_MSFT,df_AMZN,df_META]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

def create_dataset(dataset):
    X, y = [], []
    for i in range(len(dataset)-60):
        feature = dataset[i:i+60]
        target = dataset[i+60]
        X.append(feature)
        y.append(target)
    X = np.array(X)  # แปลง list เป็น numpy array
    y = np.array(y)  # แปลง list เป็น numpy array
    return torch.tensor(X, dtype=torch.float32), torch.tensor(y, dtype=torch.float32)

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size_1, hidden_size_2, output_size):
        super(LSTMModel, self).__init__()
        self.lstm1 = nn.LSTM(input_size, hidden_size_1, batch_first=True)
        self.lstm2 = nn.LSTM(hidden_size_1, hidden_size_2, batch_first=True)

        self.fc1 = nn.Linear(hidden_size_2, 25)
        self.fc2 = nn.Linear(25, output_size)

    def forward(self, x):
        # hidden state and cell state สำหรับ lstm1
        h_0 = torch.zeros(1, x.size(0), hidden_size_1).to(x.device)  # (num_layers, batch_size, hidden_size)
        c_0 = torch.zeros(1, x.size(0), hidden_size_1).to(x.device)

        # LSTM Layer 1
        out, (h_0, c_0) = self.lstm1(x, (h_0, c_0))

        # hidden state and cell state สำหรับ lstm2
        h_1 = torch.zeros(1, x.size(0), hidden_size_2).to(x.device)  # (num_layers, batch_size, hidden_size)
        c_1 = torch.zeros(1, x.size(0), hidden_size_2).to(x.device)

        # LSTM Layer 2
        out, _ = self.lstm2(out, (h_1, c_1))

        # ใช้ค่า output ของ timestep สุดท้าย
        out = out[:, -1, :]

        # Fully connected layers
        out = self.fc1(out)
        out = self.fc2(out)
        return out

# %%
torch.cuda.is_available()
# Out:
# False

# %%
for data_model, com_name in zip(arr_dataset, company_name):
    
    
    data = data_model.filter(['Close'])  # กรองเฉพาะคอลัมน์ 'Close'
    dataset = data.values  # แปลง DataFrame เป็น numpy array
    scaler = MinMaxScaler(feature_range=(0,1))  # สร้างตัวปรับสเกล MinMaxScaler
    dataset = scaler.fit_transform(dataset)  # ทำการปรับสเกลข้อมูล
    
    
    train_size = int(len(dataset) * 0.70)
    train, test = dataset[:train_size], dataset[train_size:]
    
    X_train, y_train = create_dataset(train)
    X_test, y_test = create_dataset(test)
    
    X_train = X_train.squeeze(1)
    y_train = y_train.to(device)
    X_test = X_test.squeeze(1)
    y_test = y_test
    
    # Hyperparameters
    input_size = 1  # ขนาดของ features (ในที่นี้เรามี 1 feature คือราคาปิด)
    hidden_size_1 = 128
    hidden_size_2 = 64
    output_size = 1  # ขนาดของ output (ราคาปิดที่ทำนายได้)
    num_epochs = 10
    batch_size = 200
    learning_rate = 0.001
    
     # สร้างโมเดล
    model = LSTMModel(input_size, hidden_size_1, hidden_size_2, output_size)
    
    # ใช้ optimizer และ loss function
    criterion = nn.MSELoss()  # Mean Squared Error loss
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    
    # DataLoader
    train_loader = DataLoader(TensorDataset(X_train, y_train), shuffle=True, batch_size=batch_size)

    # ฝึกโมเดล
    for epoch in range(num_epochs):
        model.train()
        for i, (x_batch, y_batch) in enumerate(train_loader):
            # Forward pass
            outputs = model(x_batch)
            loss = criterion(outputs, y_batch)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        if epoch % 1 == 0:
              
            model.eval()
            with torch.no_grad():
                y_pred_train = model(X_train)
                train_rmse = torch.sqrt(criterion(y_pred_train, y_train))
                
                y_pred_test = model(X_test)
                test_rmse = torch.sqrt(criterion(y_pred_test, y_test))
                
            print(f"{com_name} Epoch {epoch}: train RMSE {train_rmse:.4f}, test RMSE {test_rmse:.4f}")
        # --- เริ่มการทำนายและ plot หลังจากฝึกเสร็จแล้ว ---
    # ทำการแปลงค่าทำนายกลับมาในสเกลดั้งเดิม
    
    model.eval()
    with torch.no_grad():
        y_pred_test = model(X_test)
    y_pred_train_original = scaler.inverse_transform(y_pred_train.numpy())
    y_train_original = scaler.inverse_transform(y_train.numpy())

    y_pred_test_original = scaler.inverse_transform(y_pred_test.numpy())
    y_test_original = scaler.inverse_transform(y_test.numpy())

    # Plot ผลลัพธ์
    plt.figure(figsize=(10,6))

    # Plot ค่าทำนายจากชุด train
    plt.subplot(2, 1, 1)
    plt.plot(y_train_original, label='Real Train Data', color='blue')
    plt.plot(y_pred_train_original, label='Predicted Train Data', color='orange')
    plt.title(f'{com_name} - Train Data')
    plt.legend()

    # Plot ค่าทำนายจากชุด test
    plt.subplot(2, 1, 2)
    plt.plot(y_test_original, label='Real Test Data', color='blue')
    plt.plot(y_pred_test_original, label='Predicted Test Data', color='orange')
    plt.title(f'{com_name} - Test Data')
    plt.legend()

    plt.tight_layout()
    plt.show()
# Out:
# APPLE Epoch 0: train RMSE 0.1758, test RMSE 0.6105
# APPLE Epoch 1: train RMSE 0.1579, test RMSE 0.5359
# APPLE Epoch 2: train RMSE 0.1561, test RMSE 0.5412
# APPLE Epoch 3: train RMSE 0.1427, test RMSE 0.4118
# APPLE Epoch 4: train RMSE 0.0838, test RMSE 0.1271
# APPLE Epoch 5: train RMSE 0.0740, test RMSE 0.0826
# APPLE Epoch 6: train RMSE 0.0447, test RMSE 0.0744
# APPLE Epoch 7: train RMSE 0.0230, test RMSE 0.0478
# APPLE Epoch 8: train RMSE 0.0178, test RMSE 0.0417
# APPLE Epoch 9: train RMSE 0.0186, test RMSE 0.0381
# GOOGLE Epoch 0: train RMSE 0.1347, test RMSE 0.3913
# GOOGLE Epoch 1: train RMSE 0.0979, test RMSE 0.4309
# GOOGLE Epoch 2: train RMSE 0.0506, test RMSE 0.1463
# GOOGLE Epoch 3: train RMSE 0.0187, test RMSE 0.0360
# GOOGLE Epoch 4: train RMSE 0.0131, test RMSE 0.0350
# GOOGLE Epoch 5: train RMSE 0.0141, test RMSE 0.0341
# GOOGLE Epoch 6: train RMSE 0.0129, test RMSE 0.0375
# GOOGLE Epoch 7: train RMSE 0.0135, test RMSE 0.0348
# ...
